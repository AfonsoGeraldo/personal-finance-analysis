# %%
from sqlalchemy import create_engine

engine = create_engine(
    'mssql+pyodbc://localhost/Testes?driver=ODBC+Driver+18+for+SQL+Server&trusted_connection=yes&TrustServerCertificate=yes'
)

# %%
import pandas as pd

query = "SELECT * FROM Transactions"
df_sql = pd.read_sql(query, engine)

print(df_sql)
# Out:
#    Id   TransDate        Category                         Description  \
# 0   1  2023-01-01          Salary                      Monthly salary
# 1   2  2023-01-01   Entertainment              Movies, concerts, etc.
# 2   3  2023-01-02  Transportation        Fuel, public transport, etc.
# 3   4  2023-01-05  Transportation        Fuel, public transport, etc.
# 4   5  2023-01-06         Housing                        Rent payment
# 5   6  2023-01-10       Groceries                     Weekly shopping
# 6   7  2023-01-15       Utilities  Electricity, water, internet bills
#
#     Amount     Type
# 0  2224.84   Income
# 1   416.39  Expense
# 2    28.61  Expense
# 3    48.12  Expense
# 4   950.00  Expense
# 5   120.35  Expense
# 6   210.00  Expense
